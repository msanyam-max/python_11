# %%
# Create Table

# %%
try:
    cursor.execute('''
        create table orders(
    	order_id integer primary key autoincrement,
    	order_status text not null,
    	order_date date,
    	customer_id integer,
    	staff_id integer,
    	foreign key (customer_id) references customers(customer_id)
    	foreign key (staff_id) references staff(staff_id)
);
        )

# %%
cursor.execute('''
    Insert into customers (first_name, last_name, phone, email, street, city)
    values
    ('Bob', 'Bahadur', '87654', 'bob@gmail.com', 'San Francisco', 'California'),
    ('Ram', 'Cooper', '54321', 'ram@gmail.com', 'Buddhanagar', 'Kathmandu'),
    ('Harry', 'Potter', '12345', 'harry@gmail.com', 'Chyasal', 'Patan');
''')
    coon.commit()
    print('Data inserted successfully.')
except:
